# %%
import pandas as pd

hotels = pd.read_csv('innvest_portfolio_hotels_data.csv')
accommodations = pd.read_csv("innvest_hotels_portfolio_accommodations.csv")

# %%
hotels
# Out:
#    hotelbrandname     hotelfullyqualifiedname hotelcountry hotelprovince  \
# 0   Hyatt Regency     Hyatt Regency Vancouver       Canada            BC
# 1        Fairmont  Fairmont Vancouver Airport       Canada            BC
# 2     Comfort Inn        Comfort Inn Edmonton       Canada            AB
# 3        Fairmont    Fairmont Hotel Macdonald       Canada            AB
# 4        Sheraton  Sheraton Eau Claire Suites       Canada            AB
# ..            ...                         ...          ...           ...
# 74    Comfort Inn         Comfort Inn Amherst       Canada            NS
# 75    Comfort Inn     Comfort inn New Glasgow       Canada            NS
# 76    Comfort Inn          Comfort Inn Sydney       Canada            NS
# 77    Comfort Inn           Comfort Inn Truro       Canada            NS
# 78    Comfort Inn        Comfort Inn Yarmouth       Canada            NS
#
#     hotelstreenumber            hotelstreetname    hotelcity hostelpostalcode  \
# ...

# %%
accommodations
# Out:
#                                         id  \
# 0     e104e0d1-0478-4168-b7b8-29b3804b1eb6
# 1     491158ac-c0a4-42bf-839a-b4539900ecd2
# 2     0d343428-4358-4e43-a45e-ebae2f5d86a3
# 3     5d20520c-ecc5-41a7-a1b5-5e0943c469f0
# 4     79472e2d-d19b-49b1-8518-ae137b447585
# ...                                    ...
# 7970  23c95fd0-d7e9-4163-954a-68a591380b25
# 7971  79ed77c0-4ac3-46e2-929c-fcc28691ceb2
# 7972  7fafe08c-640e-40cd-83e9-b6a2efaa0775
# 7973  3c7a41d1-7bb5-491a-8fff-cb42674da654
# 7974  7733bd18-2f32-4b73-a9a8-08c78b5eb8e7
#
#                                   hotel_id accommodationtype  description  \
# 0     36d6e0b4-b4e2-470b-81b8-06ba8bc650ff             suite  lorem ipsum
# 1     36d6e0b4-b4e2-470b-81b8-06ba8bc650ff             suite  lorem ipsum
# 2     36d6e0b4-b4e2-470b-81b8-06ba8bc650ff             suite  lorem ipsum
# 3     36d6e0b4-b4e2-470b-81b8-06ba8bc650ff             suite  lorem ipsum
# ...

# %%
accommodations.columns
# Out:
# Index(['id', 'hotel_id', 'accommodationtype', 'description', 'squarefootage',
#        'maxoccupancy', 'numbeds', 'bedsize', 'roomnumber', 'roomfloor',
#        'amenities', 'occupied'],
#       dtype='object')
